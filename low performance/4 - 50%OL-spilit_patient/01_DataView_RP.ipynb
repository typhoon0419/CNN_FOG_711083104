# %%
import pandas as pd
import numpy as np

import os

# %%
data_path = os.getcwd() + "/dataset/total_test.csv"
# features = ["A_F", "A_V", "A_L", "L_F", "L_V", "L_L", "T_F", "T_V", "T_L"]

dataset = pd.read_csv(data_path)
time = list(dataset['time'])
Action = dataset['Action']

AVdata = dataset[["T_F"]].values
TVdata = dataset[["T_V"]].values
LVdata = dataset[["T_L"]].values


dataframe = dataset[["T_F", "T_V", "T_L"]].values
dataset = dataset[["T_F", "T_V", "T_L", "Action"]].values

window_length = int(1*64)
total_windows = int((len(dataset))/window_length)

# %%
AVdata = np.array(AVdata)
LVdata = np.array(LVdata)
TVdata = np.array(TVdata)

# %%
Tsensor = np.multiply(AVdata, AVdata) + np.multiply(LVdata, LVdata) + np.multiply(TVdata, TVdata)
Tsensor = np.sqrt(Tsensor)

# %%
dataframe = (dataframe-dataframe.mean())/dataframe.std()
Tsensor = (Tsensor-Tsensor.mean())/Tsensor.std()

# %%
indices = time
groups = []
group_count = 0
temp = []
lenOfGroup = []
length_count = 0

for i in range(len(indices)):
    if i == (len(indices) - 1):
        temp.append(indices[i])
        length_count = length_count + 1

        groups.append(temp)
        lenOfGroup.append(length_count)
        length_count = 0
        temp = []
        break
    temp.append(indices[i])
    length_count = length_count + 1
    if (indices[i+1] - 20 > indices[i]):
        group_count = group_count + 1

        lenOfGroup.append(length_count)
        length_count = 0

        groups.append(temp)
        temp = []

del temp, indices, group_count, length_count, i

# %%
countOfUndivisible = 0
total_windows_with_overlap = 0

start_index = 0

stop_Indexs = []
stop_Index = -window_length


for lengths in lenOfGroup:
    stop_Index = stop_Index + lengths
    stop_Indexs.append(stop_Index)
    total_windows_with_overlap = total_windows_with_overlap + int(lengths/window_length*2 -1)
    
    if lengths % (window_length/2) != 0:
        countOfUndivisible = countOfUndivisible + 1
        print(lengths)

print(countOfUndivisible)
del countOfUndivisible, lengths
# Out:
# 0

# %%
X_ = np.empty((total_windows_with_overlap, window_length))
y_ = np.empty((total_windows_with_overlap, 1))

stop_Index = 0
window_count = 0

for window in range(total_windows_with_overlap):
    for i in range(window_length):
        if i == 0:
            y_[window] = dataset[int(window_count*window_length), 3]
        
        if int(window_count*window_length)<len(dataset)-window_length-1:
            X_[window, i] = Tsensor[int(window_count*window_length) + i]
        
        if stop_Index < len(stop_Indexs):
            if int(window_count*window_length) == stop_Indexs[stop_Index]:
                window_count = window_count + 0.5
                stop_Index = stop_Index + 1

        if window == total_windows_with_overlap-1:
            X_[window, i] = Tsensor[int((window_count-0.5)*window_length) + i]
    window_count = window_count + 0.5

# %%
# # Create a toy time series using the sine function
# time_points = np.linspace(0, 4 * np.pi, 64)
# x = X_[0]
# X = np.array([x])

# # Recurrence plot transformation
# rp = RecurrencePlot(threshold=np.pi/18)
# X_rp = rp.transform(X)

# # Plot the time series and its recurrence plot
# fig = plt.figure(figsize=(6, 6))

# gs = fig.add_gridspec(2, 2,  width_ratios=(2, 7), height_ratios=(2, 7),
#                       left=0.1, right=0.9, bottom=0.1, top=0.9,
#                       wspace=0.05, hspace=0.05)

# # Define the ticks and their labels for both axes
# time_ticks = np.linspace(0, 4 * np.pi, 9)
# time_ticklabels = [r'$0$', r'$\frac{\pi}{2}$', r'$\pi$',
#                    r'$\frac{3\pi}{2}$', r'$2\pi$', r'$\frac{5\pi}{2}$',
#                    r'$3\pi$', r'$\frac{7\pi}{2}$', r'$4\pi$']
# value_ticks = [-1, 0, 1]
# reversed_value_ticks = value_ticks[::-1]

# # # Plot the time series on the left with inverted axes
# # ax_left = fig.add_subplot(gs[1, 0])
# # ax_left.plot(x, time_points)
# # ax_left.set_xticks(reversed_value_ticks)
# # ax_left.set_xticklabels(reversed_value_ticks, rotation=90)
# # ax_left.set_yticks(time_ticks)
# # ax_left.set_yticklabels(time_ticklabels, rotation=90)
# # ax_left.invert_xaxis()

# # # Plot the time series on the top
# # ax_top = fig.add_subplot(gs[0, 1])
# # ax_top.plot(time_points, x)
# # ax_top.set_xticks(time_ticks)
# # ax_top.set_xticklabels(time_ticklabels)
# # ax_top.set_yticks(value_ticks)
# # ax_top.set_yticklabels(value_ticks)
# # ax_top.xaxis.tick_top()

# # Plot the recurrence plot on the bottom right
# ax_rp = fig.add_subplot(gs[1, 1])
# ax_rp.imshow(X_rp[0], cmap='binary', origin='lower',
#              extent=[0, 4 * np.pi, 0, 4 * np.pi])
# ax_rp.set_xticks([])
# ax_rp.set_yticks([])

# plt.show()

# %%
from pyts.image import RecurrencePlot
import matplotlib.pyplot as plt

# %%
save_path = os.getcwd() + "/dataset/RPtest/"
rp = RecurrencePlot(threshold=0.3)

for i in range(total_windows_with_overlap):
    final_path = save_path + str(int(y_[i]))
    x = X_[i]
    X = np.array([x])
    X_rp = rp.transform(X)

    fig = plt.figure(figsize=(1, 1))
    ax_rp = fig.add_subplot()
    ax_rp.imshow(X_rp[0], cmap='binary', origin='lower')
    ax_rp.set_xticks([])
    ax_rp.set_yticks([])

    image_path = final_path + '/' + str(i) + '.png'
    plt.savefig(image_path, bbox_inches='tight')
    plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ESALAB~1\AppData\Local\Temp/ipykernel_19444/2766119018.py in <module>
#       9
#      10     fig = plt.figure(figsize=(1, 1))
# ---> 11     ax_rp = fig.add_subplot()
#      12     ax_rp.imshow(X_rp[0], cmap='binary', origin='lower')
#      13     ax_rp.set_xticks([])
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     630
#     631         self._rasterization_zorder = None
# --> 632         self.cla()
#     633
#     634         # funcs used to format x and y - fall back on major formatters
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1247         self.containers = []
#    1248
# -> 1249         self.grid(False)  # Disable grid on init to use rcParameter
#    1250         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1251                   axis=mpl.rcParams['axes.grid.axis'])
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axes\_base.py in grid(self, visible, which, axis, **kwargs)
#    3224         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3225         if axis in ['x', 'both']:
# -> 3226             self.xaxis.grid(visible, which=which, **kwargs)
#    3227         if axis in ['y', 'both']:
#    3228             self.yaxis.grid(visible, which=which, **kwargs)
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axis.py in grid(self, visible, which, **kwargs)
#    1432             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1433                                 if visible is None else visible)
# -> 1434             self.set_tick_params(which='major', **gridkw)
#    1435         self.stale = True
#    1436
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     871             if which in ['major', 'both']:
#     872                 self._major_tick_kw.update(kwtrans)
# --> 873                 for tick in self.majorTicks:
#     874                     tick._apply_params(**kwtrans)
#     875             if which in ['minor', 'both']:
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     591                 instance.majorTicks = []
#     592                 tick = instance._get_tick(major=True)
# --> 593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#     595             else:
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     590             if self._major:
#     591                 instance.majorTicks = []
# --> 592                 tick = instance._get_tick(major=True)
#     593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2055         else:
#    2056             tick_kw = self._minor_tick_kw
# -> 2057         return XTick(self.axes, 0, major=major, **tick_kw)
#    2058
#    2059     def set_label_position(self, position):
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     429         )
#     430         trans, va, ha = self._get_text2_transform()
# --> 431         self.label2.set(
#     432             x=0, y=1,
#     433             verticalalignment=va, horizontalalignment=ha, transform=trans,
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     170         # Update bbox last, as it depends on font properties.
#     171         bbox = kwargs.pop("bbox", sentinel)
# --> 172         super().update(kwargs)
#     173         if bbox is not sentinel:
#     174             self.set_bbox(bbox)
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1053         """
#    1054         ret = []
# -> 1055         with cbook._setattr_cm(self, eventson=False):
#    1056             for k, v in props.items():
#    1057                 # Allow attributes we want to be able to update through
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# c:\Users\ESA LAB\anaconda3\envs\HighHeelWhatever\lib\site-packages\matplotlib\cbook\__init__.py in _setattr_cm(obj, **kwargs)
#    2020     origs = {}
#    2021     for attr in kwargs:
# -> 2022         orig = getattr(obj, attr, sentinel)
#    2023         if attr in obj.__dict__ or orig is sentinel:
#    2024             # if we are pulling from the instance dict or the object
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize=(10, 2))
x = range(0, len(Tsensor))
y = Tsensor
color = Action
plt.ylim(-10,20)
plt.style.use("ggplot") 

plt.plot(x, y, 'r')

# %%
fig, ax = plt.subplots(figsize = (10, 4))
start_index = 1000
stop_Index = 1064


ax.plot(x[start_index: stop_Index], y[start_index: stop_Index])

ax.pcolorfast(ax.set_xlim(start_index, stop_Index), ax.get_ylim(), Action[start_index: stop_Index].values[np.newaxis],cmap='Set3', alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 4))
start_index = 800000
stop_Index = 800064


ax.plot(x[start_index: stop_Index], y[start_index: stop_Index])

ax.pcolorfast(ax.set_xlim(start_index, stop_Index), ax.get_ylim(), Action[start_index:stop_Index].values[np.newaxis],cmap='Set3', alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 4))
start_index = len(x)-64
stop_Index = len(x)


ax.plot(x[start_index: stop_Index], y[start_index: stop_Index])

ax.pcolorfast(ax.set_xlim(start_index, stop_Index), ax.get_ylim(), Action[start_index: stop_Index].values[np.newaxis],cmap='Set3', alpha=0.3)
plt.show()

# %%
TVdata = (TVdata-TVdata.mean())/TVdata.std()

# %%
fig, ax = plt.subplots(figsize = (10, 4))
start_index = 1000
stop_Index = 1064


ax.plot(TVdata[start_index: stop_Index], y[start_index: stop_Index])

ax.pcolorfast(ax.set_xlim(start_index, stop_Index), ax.get_ylim(), Action[start_index: stop_Index].values[np.newaxis],cmap='Set3', alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 4))
start_index = 800000
stop_Index = 800064


ax.plot(TVdata[start_index: stop_Index], y[start_index: stop_Index])

ax.pcolorfast(ax.set_xlim(start_index, stop_Index), ax.get_ylim(), Action[start_index:stop_Index].values[np.newaxis],cmap='Set3', alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 4))
start_index = len(x)-64
stop_Index = len(x)


ax.plot(TVdata[start_index: stop_Index], y[start_index: stop_Index])

ax.pcolorfast(ax.set_xlim(start_index, stop_Index), ax.get_ylim(), Action[start_index: stop_Index].values[np.newaxis],cmap='Set3', alpha=0.3)
plt.show()
